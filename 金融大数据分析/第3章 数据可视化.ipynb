# %% [markdown]
# # 二维绘图

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(1000)
y=np.random.standard_normal(20)
x=range(len(y))

# %%
plt.plot(x,y)

# %%
plt.plot(y) # 把数组的索引自动替换成x的值

# %%
plt.plot(y.cumsum())

# %%
plt.plot(y.cumsum())
plt.grid(True)
plt.axis('tight')
# Out:
# (-0.9500000000000001, 19.95, -2.322818663749045, 0.5655085808655865)

# %%
plt.plot(y.cumsum())
plt.grid(True)
plt.xlim(-1, 20)
plt.ylim(np.min(y.cumsum()) -1, np.max(y.cumsum()) +1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
plt.figure(figsize=(7,4))  # 设置图像大小
plt.plot(y.cumsum(), 'b', lw=1.5) # 设置线的宽度
plt.plot(y.cumsum(), 'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A simple plot')
# Out:
# Text(0.5, 1.0, 'A simple plot')

# %%
np.random.seed(2000)
# 生成20行，2两列的数据结构
y = np.random.standard_normal((20,2)).cumsum(axis=0)
y
# Out:
# array([[ 1.73673761,  1.89791391],
#        [-0.37003581,  1.74900181],
#        [ 0.21302575, -0.51023122],
#        [ 0.35026529, -1.21144444],
#        [-0.27051479, -1.6910642 ],
#        [ 0.93922398, -2.76624806],
#        [ 1.74614319, -3.05703153],
#        [ 1.52519555, -3.22618757],
#        [ 2.62602999, -3.14367705],
#        [ 2.6216544 , -4.8662353 ],
#        [ 3.67921082, -7.38414811],
#        [ 1.7685707 , -6.07769276],
#        [ 2.19296834, -6.54686084],
#        [ 1.18689581, -7.46878388],
#        [ 1.81330034, -7.11160718],
#        [ 1.79458178, -6.89043591],
#        [ 2.49318589, -6.05592589],
#        [ 0.82754806, -8.95736573],
#        [ 0.77890953, -9.00274406],
#        [ 2.25424343, -9.51643749]])

# %%
plt.figure(figsize=(7,4))
# 默认情况
plt.plot(y, lw=1.5)
plt.plot(y, 'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple plot')
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %%
plt.figure(figsize=(7,4))
# 分别生成两条的情况
plt.plot(y[:,0], lw=1.5, label='1st')
plt.plot(y[:,1], lw=1.5, label= '2nd')
plt.plot(y, 'ro')
plt.grid(True)
plt.legend(loc=0)  # 说明信息
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple plot')
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %%
y
# Out:
# array([[ 1.73673761,  1.89791391],
#        [-0.37003581,  1.74900181],
#        [ 0.21302575, -0.51023122],
#        [ 0.35026529, -1.21144444],
#        [-0.27051479, -1.6910642 ],
#        [ 0.93922398, -2.76624806],
#        [ 1.74614319, -3.05703153],
#        [ 1.52519555, -3.22618757],
#        [ 2.62602999, -3.14367705],
#        [ 2.6216544 , -4.8662353 ],
#        [ 3.67921082, -7.38414811],
#        [ 1.7685707 , -6.07769276],
#        [ 2.19296834, -6.54686084],
#        [ 1.18689581, -7.46878388],
#        [ 1.81330034, -7.11160718],
#        [ 1.79458178, -6.89043591],
#        [ 2.49318589, -6.05592589],
#        [ 0.82754806, -8.95736573],
#        [ 0.77890953, -9.00274406],
#        [ 2.25424343, -9.51643749]])

# %%
y[:,0]
# Out:
# array([ 1.73673761, -0.37003581,  0.21302575,  0.35026529, -0.27051479,
#         0.93922398,  1.74614319,  1.52519555,  2.62602999,  2.6216544 ,
#         3.67921082,  1.7685707 ,  2.19296834,  1.18689581,  1.81330034,
#         1.79458178,  2.49318589,  0.82754806,  0.77890953,  2.25424343])

# %%
# 这样是有问题的
y[:,0] = y[:,0] * 100
plt.figure(figsize=(7,4))
# 分别生成两条的情况
plt.plot(y[:,0], lw=1.5, label='1st')
plt.plot(y[:,1], lw=1.5, label= '2nd')
plt.plot(y, 'ro')
plt.grid(True)
plt.legend(loc=0)  # 说明信息
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A Simple plot')
# Out:
# Text(0.5, 1.0, 'A Simple plot')

# %%
# 双轴图
fig,ax1 = plt.subplots()
plt.plot(y[:,0], 'b', lw=1.5, label='1st')
plt.plot(y[:,1], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A simple plot')
ax2 = ax1.twinx()
plt.plot(y[:,1], 'g', lw=1.5, label='2nd')
plt.plot(y[:,1], 'ro')
plt.legend(loc= 0)
plt.ylabel('value 2nd')
# Out:
# Text(0, 0.5, 'value 2nd')

# %%
# l两张图
# plt.subplot 使用三个数（numrows, numcols, fignum）
# 211 两行一列，第一张图上
plt.figure(figsize=(7,5))
plt.subplot(211)
plt.plot(y[:,0], 'b', lw=1.5, label='1st')
plt.plot(y[:,0], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('vlaue 1st')
plt.title('A simple plot')
plt.subplot(212)
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc=0)
plt.ylabel('value 2nd')
# Out:
# Text(0, 0.5, 'value 2nd')

# %%
plt.figure(figsize=(9,4))
plt.subplot(121)
plt.plot(y[:,0], 'b', lw=1.5, label='1st')
plt.plot(y[:,0], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('vlaue 1st')
plt.title('A simple plot')
#plt.subplot(212)
plt.subplot(122)
#plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.bar(np.arange(len(y)), y[:,1], color='g', label='2nd')
#plt.plot(y[:, 1], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 2nd')
# Out:
# Text(0, 0.5, 'value 2nd')

# %%
# 散点图

# %%
y = np.random.standard_normal((1000, 2))

# %%
plt.figure(figsize=(7,5))
plt.plot(y[:,0], y[:,1], 'ro')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
plt.figure(figsize=(7,5))
plt.plot(y[:,0], y[:,1], marker='o')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
# 三维图

# %%
c = np.random.randint(0, 10, len(y))
print(c)
# Out:
# [3 1 6 8 1 1 2 2 0 9 6 9 3 4 2 9 0 0 1 6 8 9 1 9 0 3 2 0 9 7 8 7 1 7 8 8 1
#  3 0 9 2 3 9 4 1 5 4 3 2 9 2 9 9 8 3 3 0 1 3 1 4 6 4 3 4 7 6 9 6 6 0 7 3 4
#  8 0 1 8 2 3 6 3 3 4 3 3 8 5 2 6 5 3 5 8 8 8 0 9 8 9 8 2 7 1 9 9 1 5 2 1 7
#  7 9 9 9 0 2 1 4 6 9 9 0 6 1 7 1 8 1 5 3 1 3 1 6 6 0 8 3 3 6 2 7 2 8 0 4 2
#  1 7 6 9 6 1 8 9 0 9 9 3 3 4 7 8 2 6 4 8 1 6 6 3 0 2 6 3 1 9 2 8 7 0 4 5 1
#  1 1 6 0 2 6 6 2 8 6 1 3 6 8 4 8 4 1 5 6 1 6 8 3 9 6 2 5 7 7 2 4 0 4 6 2 5
#  6 8 4 5 1 7 3 3 6 0 6 6 8 1 8 5 4 0 8 8 4 6 1 1 1 8 2 9 9 1 8 0 7 4 1 8 9
#  5 4 6 8 7 2 0 5 0 6 3 9 0 0 4 7 9 7 8 8 1 9 5 9 3 7 6 8 3 5 8 6 3 0 9 7 0
#  0 3 7 7 4 2 7 7 0 1 6 1 6 4 9 0 4 6 7 5 1 0 8 5 4 9 7 3 8 8 5 6 0 5 6 6 3
#  7 6 0 7 4 5 6 3 2 7 3 3 6 9 9 9 1 3 7 3 1 7 9 1 5 9 4 2 4 6 8 6 1 5 8 2 5
#  6 3 6 1 7 3 7 6 6 7 7 7 7 7 0 1 3 0 0 0 9 8 6 7 5 4 5 5 9 9 0 2 1 0 8 2 8
#  3 6 1 9 5 2 0 0 3 5 1 7 4 4 5 5 0 5 6 4 6 0 3 8 5 3 7 5 9 5 1 3 4 4 8 1 6
# ...

# %%
plt.figure(figsize=(7,5))
# scatter 特有的函数 
plt.scatter(y[:,0], y[:,1], c=c, marker='o')
plt.colorbar()
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
plt.figure(figsize=(7,4))
plt.hist(y, label=['1st', '2nd'], bins=25)
plt.grid(True)
plt.xlabel('vlaue')
plt.ylabel('frequency')
plt.title('History')
# Out:
# Text(0.5, 1.0, 'History')

# %%
# 颜色堆积
plt.figure(figsize=(7,4))
plt.hist(y, label=['1st', '2nd'], color=['b', 'g'], stacked=True, bins=25)
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('vlaue')
plt.ylabel('frequency')
plt.title('History')
# Out:
# Text(0.5, 1.0, 'History')

# %%
# 箱体图
fig,ax = plt.subplots(figsize=(7,4))
plt.boxplot(y)
plt.grid(True)
# 设置图表实例属性
plt.setp(ax, xticklabels=['1st', '2nd'])
plt.xlabel('vlaue')
plt.ylabel('frequency')
plt.title('boxplot')
# Out:
# Text(0.5, 1.0, 'boxplot')

# %%
# 二维绘图举例

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def func(x):
    return 0.5*np.exp(x) + 1

# %%
a,b = 0.5, 1.5
x = np.linspace(0,2)
y = func(x)

# %%
fig,ax = plt.subplots(figsize=(7,5))
plt.plot(x,y, 'b', lw=2)
# 画曲线
plt.ylim(ymin=0)
# Out:
# /Users/cuijl/.pyenv/versions/3.6.0/envs/rqalpha_3.6.0/lib/python3.6/site-packages/matplotlib/axes/_base.py:3449: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
#   alternative='`bottom`', obj_type='argument')
# (0, 4.8542544519385915)

# %%
Ix = np.linspace(a,b)
Iy = func(Ix)
verts = [(a,0)] + list(zip(Ix,Iy)) + [(b,0)]
# Out:
# [0.5        0.52040816 0.54081633 0.56122449 0.58163265 0.60204082
#  0.62244898 0.64285714 0.66326531 0.68367347 0.70408163 0.7244898
#  0.74489796 0.76530612 0.78571429 0.80612245 0.82653061 0.84693878
#  0.86734694 0.8877551  0.90816327 0.92857143 0.94897959 0.96938776
#  0.98979592 1.01020408 1.03061224 1.05102041 1.07142857 1.09183673
#  1.1122449  1.13265306 1.15306122 1.17346939 1.19387755 1.21428571
#  1.23469388 1.25510204 1.2755102  1.29591837 1.31632653 1.33673469
#  1.35714286 1.37755102 1.39795918 1.41836735 1.43877551 1.45918367
#  1.47959184 1.5       ]
# [1.82436064 1.84135717 1.85870413 1.87640875 1.8944784  1.9129206
#  1.93174305 1.95095357 1.97056017 1.99057102 2.01099445 2.03183897
#  2.05311325 2.07482617 2.09698675 2.11960424 2.14268806 2.16624781
#  2.19029331 2.21483458 2.23988184 2.26544552 2.29153626 2.31816494
#  2.34534265 2.3730807  2.40139065 2.43028429 2.45977365 2.48987102
#  2.52058894 2.55194019 2.58393783 2.6165952  2.64992589 2.68394379
# ...

# %%
from matplotlib.patches import Polygon

# %%
Ix = np.linspace(a,b)
Iy = func(Ix)
verts = [(a,0)] + list(zip(Ix,Iy)) + [(b,0)]
poly = Polygon(verts, facecolor='0.7', edgecolor='0.5')

fig,ax = plt.subplots(figsize=(7,5))
plt.plot(x,y, 'b', lw=2)
# 画曲线
plt.ylim(bottom=0)
ax.add_patch(poly)

# %%
Ix = np.linspace(a,b)
Iy = func(Ix)
verts = [(a,0)] + list(zip(Ix,Iy)) + [(b,0)]
poly = Polygon(verts, facecolor='0.7', edgecolor='0.5')
fig,ax = plt.subplots(figsize=(7,5))
plt.plot(x,y, 'b', lw=2)
# 画曲线
plt.ylim(bottom=0)
ax.add_patch(poly)

plt.text(0.5 * (a + b), 1, r"$\int_a^b f(x)\mathrm{d}x$",
         horizontalalignment='center', fontsize=20)
plt.figtext(0.9, 0.075, '$x$')
plt.figtext(0.075, 0.9, '$f(x)$')
ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([func(a), func(b)])
ax.set_yticklabels(('$f(a)$', '$f(b)$'))
plt.grid(True)

# %%
# 金融作图

# %%
import mpl_finance as mpf

# %%
# 3D绘图

# %%
from mpl_tool
